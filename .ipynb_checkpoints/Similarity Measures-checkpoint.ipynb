# %%
import datetime
import pandas as pd
import numpy as np
from sklearn.metrics import jaccard_score
import operator

# %%
dataTr = pd.read_csv('dataTr.csv')

# %%
dataTr.columns =['Index', 'Rank', 'Name', 'City', 'State', 'PubOrPriv',
                 'UndergradPop', 'StudentPop', 'NetPrice', 'AverageGrantAid', 'TotalAnnualCost', 'AlumniSalary', 'AcceptanceRate', 'SATLower', 'SATUpper', 'ACTLower', 'ACTUpper', 'Website']
dataTr.head()
# Out:
#    Index  Rank                                   Name       City State  \
# 0      0   1.0                     Harvard University  Cambridge    MA
# 1      1   2.0                    Stanford University   Stanford    CA
# 2      2   3.0                        Yale University  New Haven    CT
# 3      3   4.0  Massachusetts Institute of Technology  Cambridge    MA
# 4      4   5.0                   Princeton University  Princeton    NJ
#
#   PubOrPriv  UndergradPop  StudentPop  NetPrice  AverageGrantAid  \
# 0   Private       13844.0     31120.0   14327.0          49870.0
# 1   Private        8402.0     17534.0   13261.0          50134.0
# 2   Private        6483.0     12974.0   18627.0          50897.0
# 3   Private        4680.0     11466.0   20771.0          43248.0
# 4   Private        5659.0      8273.0    9327.0          48088.0
#
#    TotalAnnualCost  AlumniSalary  AcceptanceRate  SATLower  SATUpper  \
# 0          69600.0      146800.0             5.0    1460.0    1590.0
# ...

# %%
# Adding extra columns

# Location
Northeast = ['PA', 'NY', 'NJ', 'ME', 'NH', 'VT', 'MA', 'CT', 'RI']
Midwest = ['ND', 'SD', 'NE', 'KS', 'MN', 'IA', 'MO', 'WI', 'IL', 'IN', 'MI', 'OH']
South = ['OK', 'TX', 'AR', 'LA', 'KY', 'TN', 'MS', 'AL', 'WV', 'MD', 'VA', 'DC', 'NC', 'SC', 'GA', 'AL', 'FL', 'DE']
West = ['WA', 'OR', 'CA', 'NV', 'ID', 'MT', 'WY', 'UT', 'AZ', 'NM', 'CO']

# Cost
# $5,000 - $15,000 → 0
# $15,001 - $30,000 → 1
# $30,001 - $45,000 → 2
# $45,001 - $60,000 → 3
# $60,001 - $75,000 → 4

for index, row in dataTr.iterrows():
    size = dataTr.loc[index]['StudentPop']
    if (size < 5000):
        dataTr.loc[index,'Size'] = 'Small'
        dataTr.loc[index,'SizeNum'] = 0
    elif (size >= 5000 and size < 15000):
        dataTr.loc[index,'Size'] = 'Medium'
        dataTr.loc[index,'SizeNum'] = 1
    else:
        dataTr.loc[index,'Size'] = 'Large'
        dataTr.loc[index,'SizeNum'] = 2
    
    state = dataTr.loc[index]['State']
    if (state in Northeast):
        dataTr.loc[index,'Location'] = 'Northeast'
        dataTr.loc[index,'LocationNum'] = 0
    elif (state in Midwest):
        dataTr.loc[index,'Location'] = 'Midwest'
        dataTr.loc[index,'LocationNum'] = 1
    elif (state in South):
        dataTr.loc[index,'Location'] = 'South'
        dataTr.loc[index,'LocationNum'] = 2
    else:
        dataTr.loc[index,'Location'] = 'West'
        dataTr.loc[index,'LocationNum'] = 3
        
    pubPrivStatus = dataTr.loc[index]['PubOrPriv']
    if (pubPrivStatus == 'Private'):
        dataTr.loc[index,'pubOrPrivNum'] = 1
    else:
        dataTr.loc[index,'pubOrPrivNum'] = 0
        
    
    cost = dataTr.loc[index]['TotalAnnualCost']
    if (cost <= 15000):
        dataTr.loc[index,'Cost'] = 0
    elif (cost > 15000 and cost <= 30000):
        dataTr.loc[index,'Cost'] = 1
    elif (cost > 30000 and cost <= 45000):
        dataTr.loc[index,'Cost'] = 2
    elif (cost > 45000 and cost <= 60000):
        dataTr.loc[index,'Cost'] = 3
    else:
         dataTr.loc[index,'Cost'] = 4

# %%
dataTr.describe()
# Out:
#             Index        Rank  UndergradPop    StudentPop      NetPrice  \
# count   78.000000   78.000000     78.000000     78.000000     78.000000
# mean   101.871795  120.974359  24226.910256  31984.141026  20752.102564
# std     97.227456  119.190666  13318.183775  13820.613043   7444.138923
# min      0.000000    1.000000   4036.000000   7022.000000   9327.000000
# 25%     28.250000   31.500000  12501.500000  22919.250000  14787.250000
# 50%     80.000000   93.000000  23396.500000  31643.000000  18522.000000
# 75%    145.000000  172.000000  32192.250000  42497.000000  26433.750000
# max    486.000000  601.000000  65100.000000  67929.000000  40336.000000
#
#        AverageGrantAid  TotalAnnualCost   AlumniSalary  AcceptanceRate  \
# count        78.000000        78.000000      78.000000       78.000000
# mean      21246.923077     55628.525641  111057.692308       43.551282
# std       14801.101666     12582.180185   13517.305111       26.244429
# ...

# %%
# print(dataTr['Size'].value_counts())
# print(dataTr['Location'].value_counts())
# print(dataTr['satAvg'].value_counts())
# print(dataTr['actAvg'].value_counts())
# print(dataTr['NetPrice'].value_counts())
# print(dataTr['AcceptanceRate'].max())

# %%
allGradData = pd.read_csv('grad.csv')
allGradData.drop(columns=allGradData.columns[0], 
        axis=1, 
        inplace=True)
allGradData.head()
# Out:
#     greV   greQ  greA  cgpa                          univName
# 0  150.0  166.0   3.0  4.00             Ohio State University
# 1  157.0  151.0   5.5  3.57              Texas A&M University
# 2  155.0  167.0   4.0  3.66  University Of California, Irvine
# 3  161.0  157.0   4.0  3.10                 Boston University
# 4  154.0  170.0   4.0  3.38           Oregon State University

# %%
#cleaning data

dataTr['Name'].replace('Texas AandM University, College Station', 'Texas A&M University', inplace=True)
allGradData['univName'].replace(['University Of California, Irvine','UC Irvine'], 'University of California, Irvine', inplace=True)
allGradData['univName'].replace(['University Of Texas At Austin', 'UT Austin', 'University Of Texas At Austin (UT Austin)'], 'University of Texas, Austin', inplace=True)
allGradData['univName'].replace('University Of Texas At Dallas', 'University of Texas, Dallas', inplace=True)
allGradData['univName'].replace(['North Carolina State University', 'NCSU (North Carolina State University)', 'North Carolina State University (NCSU)'], 'North Carolina State University, Raleigh', inplace=True)
allGradData['univName'].replace(['University Of Californa, Los Angeles (UCLA)', 'University Of California, Los Angeles (UCLA)', 'UCLA'], 'University of California, Los Angeles', inplace=True)
allGradData['univName'].replace(['University Of Wisconsin-Madison', 'University Of Wisconsin - Madison', 'University Of Wisconsin, Madison', 'The University Of Wisconsin - Madison'], 'University of Wisconsin, Madison', inplace=True)
allGradData['univName'].replace('Purdue University - West Lafayette', 'Purdue University', inplace=True)
allGradData['univName'].replace(['University Of Washington', '"University Of Washington Seattle'], 'University of Washington, Seattle', inplace=True)
allGradData['univName'].replace(['UC San Diego (UCSD)', 'UCSD (University Of California, San Diego)', 'UCSD', 'University Of California, San Diego (UCSD)'], 'University of California, San Diego', inplace=True)
allGradData['univName'].replace('Indiana University Bloomington', 'Indiana University, Bloomington', inplace=True)
allGradData['univName'].replace(['University Of California, Davis', 'Uc Davis', 'UC Davis'], 'University of California, Davis', inplace=True)
allGradData['univName'].replace(['University Of Illinois At Urbana-Champaign', 'UIUC'], 'University of Illinois, Urbana-Champaign', inplace=True)
allGradData['univName'].replace('University Of Colorado Boulder', 'University of Colorado Colorado Springs', inplace=True)
allGradData['univName'].replace('Washington University in St. Louis (WashU/WUSTL)', 'Washington University in St. Louis', inplace=True)
allGradData['univName'].replace('Carnegie Mellon University (CMU)', 'Carnegie Mellon University', inplace=True)
allGradData['univName'].replace(['UC Berkeley','University Of California, Berkeley (UCB)'], 'University of California, Berkeley', inplace=True)
allGradData['univName'].replace(['Penn State (Pennsylvania State University)', 'Penn State University'], 'Pennsylvania State University', inplace=True)
allGradData['univName'].replace(['University Of Southern California (USC)', 'USC', 'The University Of Southern California (USC)', 'University Of Southern California'], 'University Of Southern California', inplace=True)
allGradData['univName'].replace('University Of Florida (Gainesville)', 'University of Florida', inplace=True)
allGradData['univName'].replace('UNC Chapel Hill', 'University of North Carolina, Chapel Hill', inplace=True)
allGradData['univName'].replace('The Ohio State University', 'Ohio State University', inplace=True)
allGradData['univName'].replace('Virginia Polytechnic And State University (Virginia Tech)', 'Virginia Tech', inplace=True)
allGradData['univName'].replace('New York University (NYU)', 'New York University', inplace=True)
allGradData['univName'].replace('(Arizona State University) ASU', 'Arizona State University, Tempe', inplace=True)
allGradData['univName'].replace('(SUNY) University At Buffalo', 'University at Buffalo (SUNY)', inplace=True)
allGradData['univName'].replace('Carnegie  Mellon University (CMU)', 'Carnegie Mellon University', inplace=True)
allGradData['univName'].replace('University Of Minnesota - Twin Cities (UMN)', 'University of Minnesota, Twin Cities', inplace=True)
allGradData['univName'].replace('Ohio State University (OSU)', 'Ohio State University', inplace=True)
allGradData['univName'].replace('University Of Pennsylvania (UPenn)', 'University of Pennsylvania', inplace=True)
allGradData['univName'].replace('Columbia  University', 'Columbia University', inplace=True)
allGradData['univName'].replace('University Of Virginia', 'University of Virginia', inplace=True)
allGradData['univName'].replace('University Of Colorado, Boulder', 'University of Colorado, Boulder', inplace=True)
allGradData['univName'].replace('University Of Michigan', 'University of Michigan, Ann Arbor', inplace=True)
allGradData['univName'].replace('University Of Minnesota', 'University of Minnesota, Twin Cities', inplace=True)
allGradData['univName'].replace('Arizona State University', 'Arizona State University, Tempe', inplace=True)
allGradData['univName'].replace('Colorado State University', 'Colorado State University, Fort Collins', inplace=True)
allGradData['univName'].replace('The University Of Chicago', 'University Of Chicago', inplace=True)
allGradData['univName'].replace('Stony Brook University', 'SUNY, Stony Brook (Stony Brook University)', inplace=True)

boston = allGradData['univName'].str.contains('Boston University', case=False)
allGradData.loc[boston, 'univName'] = 'Boston University'

maryland = allGradData['univName'].str.contains('University Of Maryland', case=False)
allGradData.loc[maryland, 'univName'] = 'University of Maryland, College Park'

allGradData['univName'] = allGradData['univName'].str.title()
allGradData['univName'] = allGradData['univName'].str.strip()
dataTr['Name'] = dataTr['Name'].str.strip()
dataTr['Name'] = dataTr['Name'].str.title()

allGradData = allGradData[allGradData.univName != 'Mcgill University']
allGradData = allGradData[allGradData.univName != 'University Of Toronto']
allGradData = allGradData[allGradData.univName != 'University Of Arizona']
allGradData = allGradData[allGradData.univName != 'University Of Kansas']
allGradData = allGradData[allGradData.univName != 'Rutgers University']
allGradData = allGradData[allGradData.univName != 'Temple University']
allGradData = allGradData[allGradData.univName != 'University Of Oxford']

# %%
grads = allGradData['univName'].unique()
# print(len(grads))
# There are 78 grad schools after cleaning

common = set(grads) & set(dataTr['Name'])
# print(common)

#remove non grad schools from Tr
dataTr = dataTr[dataTr['Name'].isin(common)]

print(len(dataTr))
dataTr

# Index column is inaccurate as its from the earlier dataset, reset it or dont use
# Out:
# 78
#      Index   Rank                                     Name              City  \
# 0        0    1.0                       Harvard University         Cambridge
# 1        1    2.0                      Stanford University          Stanford
# 2        2    3.0                          Yale University         New Haven
# 4        4    5.0                     Princeton University         Princeton
# 5        5    6.0               University Of Pennsylvania      Philadelphia
# ..     ...    ...                                      ...               ...
# 253    253  308.0                   University Of Kentucky         Lexington
# 257    257  313.0                 University Of Cincinnati        Cincinnati
# 418    418  513.0                 Georgia State University           Atlanta
# 440    440  544.0  University Of Colorado Colorado Springs  Colorado Springs
# 486    486  601.0                   Wayne State University           Detroit
#
# ...

# %%
# dataTr.to_csv('finalData.csv')
allGradData.to_csv('cleanedGradData.csv')

# %%
allGradData.head()
# Out:
#     greV   greQ  greA  cgpa                          univName
# 0  150.0  166.0   3.0  4.00             Ohio State University
# 1  157.0  151.0   5.5  3.57              Texas A&M University
# 2  155.0  167.0   4.0  3.66  University Of California, Irvine
# 3  161.0  157.0   4.0  3.10                 Boston University
# 4  154.0  170.0   4.0  3.38           Oregon State University

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataTr2 = dataTr[['Rank', 'StudentPop', 'TotalAnnualCost', 'AcceptanceRate', 'SATUpper', 'ACTUpper']]
sns.heatmap(dataTr2.corr(), vmin=-1, vmax=1, annot=True);

# %%
allGradData.groupby(level=0).describe()
