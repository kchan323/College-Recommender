# %%
import pandas as pd
import numpy as np
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.spatial.distance.cosine.html
from scipy.spatial.distance import cosine
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.spatial.distance.jaccard.html
from scipy.spatial.distance import jaccard

# %%
input_cost = 1
    # a) $5,000 - $15,000 --> 10,000
    # b) $15,001 - $30,000 --> 22,500
    # c) $30,001 - $45,000 --> 37,500
    # d) $45,001 - $60,000 --> 52,500
    # e) $60,001 - $75,000 --> 67,500
input_puborpriv = 1
    # a) public --> 0
    # b) private --> 1
input_size = 1
    # a) small --> 2,500
    # b) medium --> 10,000
    # c) large --> 20,000
input_location = 1
    # a) northeast --> 0
    # b) midwest --> 1
    # c) south --> 2
    # d) west --> 3

# dependent on user
user_inputs = [input_cost, input_puborpriv, input_size, input_location]
weights = [40, 30, 20, 10]

# cosine similarity
x1 = np.array([2, 3, 1, 0])
y1 = np.array([2, 3, 0, 0])
print('cosine similarity: ' + str(1 - cosine(x1, y1, weights)))

# jaccard similarity
x2 = np.array([0, 2, 1, 2])
y2 = np.array([0, 1, 2, 2])
print('jaccard similarity: ' + str(1 - jaccard(x2, y2, weights)))
# Out:
# cosine similarity: 0.9775252199076787
# jaccard similarity: 0.16666666666666663

# %%
finalData = pd.read_csv('finalData.csv')
cosine_similarity_scores = []
jaccard_similarity_scores = []
for index, row in finalData.iterrows():
    name = finalData.loc[index,'Name']
    cost = finalData.loc[index,'Cost'] + 1
    pubOrPriv = finalData.loc[index,'pubOrPrivNum'] + 1
    size = finalData.loc[index,'SizeNum'] + 1
    state = finalData.loc[index,'LocationNum'] + 1
    school_info = [cost, pubOrPriv, size, state]
    cosine_score = 1 - cosine(user_inputs, school_info, weights)
    cosine_similarity_scores.append(cosine_score)
    jaccard_score = 1 - jaccard(user_inputs, school_info, weights)
    jaccard_similarity_scores.append(jaccard_score)
    print (user_inputs)
    print(school_info)
    print(weights)
    print(cosine(user_inputs, school_info, weights))
    print(cosine_score)

cosine_ranked_schools_scores = np.sort(-1*np.array(cosine_similarity_scores))
cosine_ranked_schools_index = np.argsort(-1*np.array(cosine_similarity_scores))
cosine_ranked_schools_names = []

jaccard_ranked_schools_scores = np.sort(-1*np.array(jaccard_similarity_scores))
jaccard_ranked_schools_index = np.argsort(-1*np.array(jaccard_similarity_scores))
jaccard_ranked_schools_names = []

for index in cosine_ranked_schools_index:
    cosine_ranked_schools_names.append(finalData.loc[index,'Name'])

for index in jaccard_ranked_schools_index:
    jaccard_ranked_schools_names.append(finalData.loc[index,'Name'])
# Out:
# [0, 0, 0, 0]
# [5.0, 2.0, 3.0, 1.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 3.0, 4.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 2.0, 1.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 2.0, 1.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 3.0, 1.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 2.0, 1.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 3.0, 1.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 1.0, 3.0, 4.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 3.0, 1.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 3.0, 2.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 3.0, 2.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 2.0, 2.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 1.0, 3.0, 2.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 2.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 2.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 3.0, 4.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 3.0, 2.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 1.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 2.0, 1.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 3.0, 1.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 2.0, 1.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 1.0, 3.0, 4.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [4.0, 1.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 2.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [4.0, 1.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [4.0, 1.0, 3.0, 4.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [4.0, 1.0, 3.0, 2.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [4.0, 1.0, 3.0, 2.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 3.0, 1.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [4.0, 1.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 1.0, 3.0, 4.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 2.0, 1.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 1.0, 3.0, 4.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 1.0, 3.0, 4.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 3.0, 2.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [4.0, 1.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [4.0, 1.0, 3.0, 1.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 3.0, 2.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [4.0, 1.0, 3.0, 2.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 2.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [4.0, 1.0, 3.0, 1.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [4.0, 1.0, 3.0, 2.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [4.0, 1.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 3.0, 1.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [4.0, 1.0, 3.0, 4.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [4.0, 1.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 3.0, 1.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [4.0, 1.0, 3.0, 2.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 3.0, 2.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 3.0, 1.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [4.0, 1.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [5.0, 2.0, 3.0, 1.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 3.0, 4.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 3.0, 4.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [4.0, 1.0, 3.0, 4.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 3.0, 1.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [4.0, 1.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 3.0, 2.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 3.0, 4.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [4.0, 1.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 3.0, 4.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [4.0, 1.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 3.0, 2.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 3.0, 3.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 2.0, 4.0]
# [40, 30, 20, 10]
# nan
# nan
# [0, 0, 0, 0]
# [3.0, 1.0, 3.0, 2.0]
# [40, 30, 20, 10]
# nan
# nan

# %%
print(cosine_ranked_schools_scores)
print(cosine_ranked_schools_names)
# Out:
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan]
# ['Harvard University', 'Syracuse University', 'Florida State University', 'University Of Delaware', 'University Of Colorado, Boulder', 'University Of Pittsburgh', 'North Carolina State University, Raleigh', 'Clemson University', 'Indiana University, Bloomington', 'University Of Connecticut', 'American University', 'Ohio State University', 'Purdue University', 'Pennsylvania State University', 'Virginia Tech', 'Texas A&M University', 'Michigan State University', 'University Of Iowa', 'Suny, Stony Brook (Stony Brook University)', 'George Mason University', 'Georgia State University', 'University Of Cincinnati', 'University Of Kentucky', 'University Of Houston', 'Oregon State University', 'University Of Central Florida', 'University Of Texas, Dallas', 'University Of Georgia', 'University Of South Florida', 'Iowa State University', 'University Of South Carolina', 'University At Buffalo (Suny)', 'University Of Oregon', 'University Of Utah', 'Arizona State University, Tempe', 'Northeastern University', 'Colorado State University, Fort Collins', 'University Of Minnesota, Twin Cities', 'University Of California, Davis', 'University Of California, Irvine', 'Johns Hopkins University', 'Rice University', 'University Of Michigan, Ann Arbor', 'University Of Notre Dame', 'Northwestern University', 'University Of Chicago', 'Georgetown University', 'Vanderbilt University', 'Columbia University', 'Cornell University', 'Duke University', 'Brown University', 'University Of Pennsylvania', 'Princeton University', 'Yale University', 'Stanford University', 'University Of California, Berkeley', 'University Of Colorado Colorado Springs', 'University Of Southern California', 'University Of Virginia', 'University Of Rochester', 'University Of California, San Diego', 'George Washington University', 'University Of Texas, Austin', 'Boston University', 'University Of Florida', 'University Of Wisconsin, Madison', 'Washington University In St. Louis', 'University Of Illinois, Urbana-Champaign', 'University Of Maryland, College Park', 'Emory University', 'University Of North Carolina, Chapel Hill', 'University Of California, Los Angeles', 'Carnegie Mellon University', 'New York University', 'Tufts University', 'University Of Washington, Seattle', 'Wayne State University']
